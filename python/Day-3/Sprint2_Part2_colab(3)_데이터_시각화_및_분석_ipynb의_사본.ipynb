# %% [markdown]
# # Sprint2_Part2_colab(3)_데이터 시각화 및 분석

# %% [markdown]
# **서울시 자전거(따릉이) 대여 데이터 셋**
# 2017년 12월 부터 2018년 11월까지의 서울시 자전거 대여 정보

# %% [markdown]
# ![SeoulBike](https://www.bikeseoul.com/img/main/main_visual.png)

# %% [markdown]
# | 컬럼명 | 의미 | 설명 |
# |------|------|----------------|
# | Date | 날짜 | Date / String |
# | Rented Bike Count | 자전거 대여 수 | Integer |
# | Hour | 시간 | 0 ~ 23 |
# | Temperature(°C) | 기온 (섭씨) | Float |
# | Humidity(%) | 습도 (%) | Integer |
# | Wind speed (m/s) | 풍속 (m/s) | Float |
# | Visibility (10m) | 가시거리 (단위: 10m) | Integer |
# | Dew point temperature(°C) | 이슬점 (섭씨) | Float |
# | Solar Radiation (MJ/m2) | 태양 복사 (MJ/m²) | Float |
# | Rainfall(mm) | 강수량 (mm) | Float |
# | Snowfall (cm) | 적설량 (cm) | Float |
# | Seasons | 계절 | Spring, Summer, Autumn, Winter |
# | Holiday | 공휴일 | Holiday / No Holiday |
# | Functioning Day | 운영일 여부 | Yes / No |

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/rngus4656/datasets/refs/heads/main/S2/SeoulBikeData_train.csv'
df = pd.read_csv(url, encoding='utf-8')
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     05/06/2018                742     1             20.0           67
# 1     30/10/2018               1442    19              8.0           52
# 2     05/10/2018                 23    12             16.6           90
# 3     11/02/2018                 93     2             -7.0           42
# 4     28/04/2018                152     5             10.9           81
# ...          ...                ...   ...              ...          ...
# 7003  01/10/2018                959    11             17.0           45
# 7004  25/07/2018                791    12             31.1           60
# 7005  15/11/2018                154     4              6.1           72
# 7006  19/11/2018                 88     4              4.5           67
# 7007  14/12/2017                382    17             -2.9           31
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  0.7              1426                       13.6
# 1                  2.1              2000                       -1.2
# 2                  1.7               518                       14.9
# 3                  1.6              2000                      -17.7
# 4                  1.7               348                        7.7
# ...                ...               ...                        ...
# 7003               4.5              1966                        4.9
# 7004               2.7              1331                       22.4
# 7005               0.5              1052                        1.4
# 7006               0.9              1175                       -1.1
# 7007               0.6              1723                      -17.7
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        0.00           0.0            0.0  Summer
# 1                        0.00           0.0            0.0  Autumn
# 2                        0.51           2.0            0.0  Autumn
# 3                        0.00           0.0            0.0  Winter
# 4                        0.00           0.0            0.0  Spring
# ...                       ...           ...            ...     ...
# 7003                     2.04           0.0            0.0  Autumn
# 7004                     1.02           0.0            0.0  Summer
# 7005                     0.00           0.0            0.0  Autumn
# 7006                     0.00           0.0            0.0  Autumn
# 7007                     0.09           0.0            0.0  Winter
#
#          Holiday Functioning Day     id
# 0     No Holiday             Yes  10019
# 1     No Holiday             Yes  13982
# 2     No Holiday             Yes  12391
# 3     No Holiday             Yes  11580
# 4     No Holiday             Yes  12042
# ...          ...             ...    ...
# 7003  No Holiday             Yes  16435
# 7004  No Holiday             Yes  13347
# 7005  No Holiday             Yes  16080
# 7006  No Holiday             Yes  12980
# 7007  No Holiday             Yes  13505
#
# [7008 rows x 15 columns]

# %%
# info에서는 어떤 특징을 알 수 있을까?

print(df.shape)
df.info()
# Out:
# (7008, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       7008 non-null   object
#  1   Rented Bike Count          7008 non-null   int64
#  2   Hour                       7008 non-null   int64
#  3   Temperature(°C)            7008 non-null   float64
#  4   Humidity(%)                7008 non-null   int64
#  5   Wind speed (m/s)           7008 non-null   float64
#  6   Visibility (10m)           7008 non-null   int64
#  7   Dew point temperature(°C)  7008 non-null   float64
#  8   Solar Radiation (MJ/m2)    7008 non-null   float64
#  9   Rainfall(mm)               7008 non-null   float64
#  10  Snowfall (cm)              7008 non-null   float64
#  11  Seasons                    7008 non-null   object
#  12  Holiday                    7008 non-null   object
#  13  Functioning Day            7008 non-null   object
#  14  id                         7008 non-null   int64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 821.4+ KB

# %%
# describe에서 알 수 있는 특징들을 정리 해보자

df.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        7008.000000  7008.000000      7008.000000  7008.000000
# mean          706.211758    11.512129        13.031107    58.317494
# std           649.132829     6.912871        11.894161    20.366061
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           190.000000     6.000000         3.700000    43.000000
# 50%           509.000000    12.000000        14.000000    57.000000
# 75%          1066.000000    17.000000        22.600000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       7008.000000       7008.000000                7008.000000
# mean           1.728567       1437.730451                   4.233790
# std            1.038034        606.505359                  13.014189
# min            0.000000         27.000000                 -30.600000
# 25%            0.900000        948.000000                  -4.400000
# 50%            1.500000       1692.500000                   5.200000
# 75%            2.300000       2000.000000                  14.925000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)            id
# count              7008.000000   7008.000000    7008.000000   7008.000000
# mean                  0.572788      0.142409       0.074886  14375.555936
# std                   0.874385      1.019976       0.437995   2526.380153
# min                   0.000000      0.000000       0.000000  10000.000000
# 25%                   0.000000      0.000000       0.000000  12183.750000
# 50%                   0.010000      0.000000       0.000000  14357.500000
# 75%                   0.930000      0.000000       0.000000  16578.250000
# max                   3.520000     24.000000       8.800000  18759.000000

# %%
# unique 고유값 개수, top 가장 많이 등장한 값, freq top값이 등장한 횟수
df.describe(exclude='number')
# Out:
#               Date Seasons     Holiday Functioning Day
# count         7008    7008        7008            7008
# unique         365       4           2               2
# top     25/10/2018  Summer  No Holiday             Yes
# freq            24    1790        6656            6771

# %%
df.isna().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# id                           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 데이터 정제 및 시각화 준비

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Datetime 타입 변환
# Date 칼럼을 읽을 수 있는 날짜 형식으로 변환한다.

# %%
# Date 칼럼이 Object형식의 DD/MM/YYYY로 되어있어 기본적인 datetime 형식으로 변환해준다.
df2 = df.copy()
df2['Date'].head()
# Out:
# 0    05/06/2018
# 1    30/10/2018
# 2    05/10/2018
# 3    11/02/2018
# 4    28/04/2018
# Name: Date, dtype: object

# %%
df2['Date'] = pd.to_datetime(df2['Date'], format='%d/%m/%Y')
df2.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2018-06-05                742     1             20.0           67
# 1 2018-10-30               1442    19              8.0           52
# 2 2018-10-05                 23    12             16.6           90
# 3 2018-02-11                 93     2             -7.0           42
# 4 2018-04-28                152     5             10.9           81
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               0.7              1426                       13.6
# 1               2.1              2000                       -1.2
# 2               1.7               518                       14.9
# 3               1.6              2000                      -17.7
# 4               1.7               348                        7.7
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                     0.00           0.0            0.0  Summer  No Holiday
# 1                     0.00           0.0            0.0  Autumn  No Holiday
# 2                     0.51           2.0            0.0  Autumn  No Holiday
# 3                     0.00           0.0            0.0  Winter  No Holiday
# 4                     0.00           0.0            0.0  Spring  No Holiday
#
#   Functioning Day     id
# 0             Yes  10019
# 1             Yes  13982
# 2             Yes  12391
# 3             Yes  11580
# 4             Yes  12042

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       7008 non-null   datetime64[ns]
#  1   Rented Bike Count          7008 non-null   int64
#  2   Hour                       7008 non-null   int64
#  3   Temperature(°C)            7008 non-null   float64
#  4   Humidity(%)                7008 non-null   int64
#  5   Wind speed (m/s)           7008 non-null   float64
#  6   Visibility (10m)           7008 non-null   int64
#  7   Dew point temperature(°C)  7008 non-null   float64
#  8   Solar Radiation (MJ/m2)    7008 non-null   float64
#  9   Rainfall(mm)               7008 non-null   float64
#  10  Snowfall (cm)              7008 non-null   float64
#  11  Seasons                    7008 non-null   object
#  12  Holiday                    7008 non-null   object
#  13  Functioning Day            7008 non-null   object
#  14  id                         7008 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 821.4+ KB

# %%
# datetime 데이터는 다음과 같이 활용할 수 있다.

# df2['year'] = df2['Date'].dt.year # 연도만 출력
df2['month'] = df2['Date'].dt.month # 월별 정보만 출력
# df2['day'] = df2['Date'].dt.day # 날짜만 출력
df2['dayname'] = df2['Date'].dt.day_name() # 요일만 출력
#df2['weekday'] = df2['Date'].dt.weekday # 한주 단위 날짜 출력 (월:0, 화:1, 수:2, 목:3, 금:4, 토:5, 일:6)
df2['weekend'] = (df2['Date'].dt.weekday >= 5).astype(int) # 주말 여부 출력 (5 이상 주말, 평일: 0, 주말: 1)
# df2['week'] = df2['Date'].dt.isocalendar().week # 1년 중 몇주차인지 출력
df2.head() # 요일정보와 월별 정보만 추출하여 새로운 칼럼 생성
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2018-06-05                742     1             20.0           67
# 1 2018-10-30               1442    19              8.0           52
# 2 2018-10-05                 23    12             16.6           90
# 3 2018-02-11                 93     2             -7.0           42
# 4 2018-04-28                152     5             10.9           81
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               0.7              1426                       13.6
# 1               2.1              2000                       -1.2
# 2               1.7               518                       14.9
# 3               1.6              2000                      -17.7
# 4               1.7               348                        7.7
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                     0.00           0.0            0.0  Summer  No Holiday
# 1                     0.00           0.0            0.0  Autumn  No Holiday
# 2                     0.51           2.0            0.0  Autumn  No Holiday
# 3                     0.00           0.0            0.0  Winter  No Holiday
# 4                     0.00           0.0            0.0  Spring  No Holiday
#
#   Functioning Day     id  month   dayname  weekend
# 0             Yes  10019      6   Tuesday        0
# 1             Yes  13982     10   Tuesday        0
# 2             Yes  12391     10    Friday        0
# 3             Yes  11580      2    Sunday        1
# 4             Yes  12042      4  Saturday        1

# %% [markdown]
# ### 칼럼명 변경 및 통합 칼럼 추가
# 강수량은 mm단위인데 적설량은 cm이다.
# 강수량과 적설량이 각각 존재하지 않아도 된다면 통합칼럼을 생성한다.

# %%
# 적설량 칼럼의 값을 mm단위로 변환
df2['Snowfall (cm)'] = df2['Snowfall (cm)'] / 10

# 칼럼 명을 cm에서 mm로 변경
df2.rename(columns={'Snowfall (cm)':'Snowfall (mm)'}, inplace=True)
df2[df2['Snowfall (mm)'] > 0]
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 7    2018-01-23                117    22            -13.9           45
# 19   2018-02-23                184    10              2.2           83
# 63   2017-12-18                 29     4             -5.4           81
# 68   2018-01-26                115    13            -13.3           28
# 102  2017-12-10                226    17              3.6           65
# ...         ...                ...   ...              ...          ...
# 6944 2018-01-24                124    16            -11.2           30
# 6953 2018-01-08                146    21              0.7           77
# 6961 2017-12-07                198     0              1.4           92
# 6983 2017-12-07                431    12              3.7           65
# 6994 2017-12-19                384    18             -3.8           42
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 7                  4.0              2000                      -23.2
# 19                 0.8               221                       -0.3
# 63                 0.7               270                       -8.1
# 68                 2.7              1889                      -27.9
# 102                4.3              1061                       -2.3
# ...                ...               ...                        ...
# 6944               4.7              2000                      -25.3
# 6953               6.7               692                       -2.8
# 6961               0.5               240                        0.2
# 6983               2.4               833                       -2.2
# 6994               3.3              2000                      -14.8
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (mm) Seasons  \
# 7                        0.00           0.0           0.09  Winter
# 19                       0.92           0.0           0.37  Winter
# 63                       0.00           0.0           0.07  Winter
# 68                       1.26           0.0           0.05  Winter
# 102                      0.03           0.0           0.04  Winter
# ...                       ...           ...            ...     ...
# 6944                     0.77           0.0           0.07  Winter
# 6953                     0.00           0.9           0.10  Winter
# 6961                     0.00           0.0           0.09  Winter
# 6983                     0.98           0.0           0.03  Winter
# 6994                     0.00           0.0           0.20  Winter
#
#          Holiday Functioning Day     id  month    dayname  weekend
# 7     No Holiday             Yes  15928      1    Tuesday        0
# 19    No Holiday             Yes  12068      2     Friday        0
# 63    No Holiday             Yes  16147     12     Monday        0
# 68    No Holiday             Yes  13430      1     Friday        0
# 102   No Holiday             Yes  12241     12     Sunday        1
# ...          ...             ...    ...    ...        ...      ...
# 6944  No Holiday             Yes  11616      1  Wednesday        0
# 6953  No Holiday             Yes  17298      1     Monday        0
# 6961  No Holiday             Yes  18323     12   Thursday        0
# 6983  No Holiday             Yes  12116     12   Thursday        0
# 6994  No Holiday             Yes  12941     12    Tuesday        0
#
# [351 rows x 18 columns]

# %%
# 강수량과 적설량이 같이 존재하는 날이 있는지 탐색
df2[(df2['Rainfall(mm)'] > 0) & (df2['Snowfall (mm)'] > 0)]
# info()를 찍어보면 총 22개의 행이 강수량과 적설량 동시 존재 하고있는 것을 확인할 수 있다.
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 377  2018-02-03                 33     6             -7.8           57
# 1042 2018-01-30                100    18             -2.3           91
# 1701 2017-12-06                204    18              1.7           90
# 1816 2018-11-24                 24     9              0.3           97
# 1912 2017-12-10                 31     9              0.2           90
# 2238 2017-12-18                 45     6             -5.2           85
# 2494 2018-01-13                174    12             -3.7           66
# 2821 2017-12-06                145     0             -2.8           77
# 2906 2018-01-30                 60    21             -1.6           91
# 3294 2017-12-18                 62    12             -1.8           83
# 3421 2017-12-31                 43     0              0.9           95
# 3572 2017-12-06                165    21              1.1           92
# 3730 2017-12-31                 65     3              0.3           91
# 4517 2018-02-03                 60     3             -4.4           80
# 4635 2018-01-10                 40     3             -6.1           70
# 4863 2018-01-10                 61     0             -5.2           82
# 5054 2017-12-10                  9     6             -0.5           90
# 5656 2018-02-23                 32     3              0.9           97
# 5826 2017-12-18                 52     9             -4.3           89
# 5989 2017-12-06                 78     3             -3.2           78
# 6671 2018-02-23                 42     0              1.7           86
# 6953 2018-01-08                146    21              0.7           77
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 377                4.8              1867                      -14.8
# 1042               0.4               202                       -3.5
# 1701               1.0                66                        0.2
# 1816               3.0                34                       -0.1
# 1912               1.0               305                       -1.2
# 2238               0.9               271                       -7.3
# 2494               1.1              1140                       -9.1
# 2821               0.0               331                       -6.2
# 2906               1.3               508                       -2.8
# 3294               1.2               351                       -4.3
# 3421               1.8                63                        0.1
# 3572               0.5               235                        0.0
# 3730               2.0               172                       -1.0
# 4517               4.3               346                       -7.3
# 4635               1.1              2000                      -10.6
# 4863               0.8               152                       -7.7
# 5054               0.9                91                       -1.9
# 5656               1.2               243                        0.4
# 5826               1.0                59                       -5.8
# 5989               0.0              1808                       -6.4
# 6671               2.7                54                       -0.3
# 6953               6.7               692                       -2.8
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (mm) Seasons  \
# 377                      0.00           0.4           0.03  Winter
# 1042                     0.00           1.4           0.20  Winter
# 1701                     0.00           0.3           0.03  Winter
# 1816                     0.00           9.1           0.71  Autumn
# 1912                     0.00           1.6           0.43  Winter
# 2238                     0.00           0.4           0.13  Winter
# 2494                     0.45           0.2           0.04  Winter
# 2821                     0.00           0.1           0.01  Winter
# 2906                     0.00           1.5           0.35  Winter
# 3294                     0.09           1.1           0.51  Winter
# 3421                     0.00           0.2           0.02  Winter
# 3572                     0.00           0.7           0.10  Winter
# 3730                     0.00           1.0           0.12  Winter
# 4517                     0.00           0.1           0.01  Winter
# 4635                     0.00           0.3           0.08  Winter
# 4863                     0.00           0.5           0.05  Winter
# 5054                     0.00           2.5           0.27  Winter
# 5656                     0.00           3.7           0.41  Winter
# 5826                     0.00           1.6           0.40  Winter
# 5989                     0.00           0.2           0.04  Winter
# 6671                     0.00           0.4           0.04  Winter
# 6953                     0.00           0.9           0.10  Winter
#
#          Holiday Functioning Day     id  month    dayname  weekend
# 377   No Holiday             Yes  18447      2   Saturday        1
# 1042  No Holiday             Yes  13202      1    Tuesday        0
# 1701  No Holiday             Yes  13429     12  Wednesday        0
# 1816  No Holiday             Yes  10092     11   Saturday        1
# 1912  No Holiday             Yes  13394     12     Sunday        1
# 2238  No Holiday             Yes  11874     12     Monday        0
# 2494  No Holiday             Yes  11190      1   Saturday        1
# 2821  No Holiday             Yes  18344     12  Wednesday        0
# 2906  No Holiday             Yes  14114      1    Tuesday        0
# 3294  No Holiday             Yes  12542     12     Monday        0
# 3421     Holiday             Yes  13851     12     Sunday        1
# 3572  No Holiday             Yes  11344     12  Wednesday        0
# 3730     Holiday             Yes  10475     12     Sunday        1
# 4517  No Holiday             Yes  15991      2   Saturday        1
# 4635  No Holiday             Yes  16614      1  Wednesday        0
# 4863  No Holiday             Yes  18671      1  Wednesday        0
# 5054  No Holiday             Yes  16515     12     Sunday        1
# 5656  No Holiday             Yes  12921      2     Friday        0
# 5826  No Holiday             Yes  18187     12     Monday        0
# 5989  No Holiday             Yes  15029     12  Wednesday        0
# 6671  No Holiday             Yes  18681      2     Friday        0
# 6953  No Holiday             Yes  17298      1     Monday        0

# %%
# rainfall + snowfall 값을 나타내는 Water Equivalent Precipitation 칼럼 생성
df2['WEP (mm)'] = df2['Rainfall(mm)'] + df2['Snowfall (mm)']
df2.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2018-06-05                742     1             20.0           67
# 1 2018-10-30               1442    19              8.0           52
# 2 2018-10-05                 23    12             16.6           90
# 3 2018-02-11                 93     2             -7.0           42
# 4 2018-04-28                152     5             10.9           81
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               0.7              1426                       13.6
# 1               2.1              2000                       -1.2
# 2               1.7               518                       14.9
# 3               1.6              2000                      -17.7
# 4               1.7               348                        7.7
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (mm) Seasons     Holiday  \
# 0                     0.00           0.0            0.0  Summer  No Holiday
# 1                     0.00           0.0            0.0  Autumn  No Holiday
# 2                     0.51           2.0            0.0  Autumn  No Holiday
# 3                     0.00           0.0            0.0  Winter  No Holiday
# 4                     0.00           0.0            0.0  Spring  No Holiday
#
#   Functioning Day     id  month   dayname  weekend  WEP (mm)
# 0             Yes  10019      6   Tuesday        0       0.0
# 1             Yes  13982     10   Tuesday        0       0.0
# 2             Yes  12391     10    Friday        0       2.0
# 3             Yes  11580      2    Sunday        1       0.0
# 4             Yes  12042      4  Saturday        1       0.0

# %%
# 시간대별 카테고리 칼럼을 생성한다.

bins = [-1, 5, 11, 17, 23]
labels = ['Dawn(0~5)', 'Morning(6~11)', 'Afternoon(12~17)', 'Evening(18~23)']
df2['Hour_cat'] = pd.cut(df2['Hour'], bins=bins, labels=labels)
df2[['Hour','Hour_cat']].head(20)
# Out:
#     Hour          Hour_cat
# 0      1         Dawn(0~5)
# 1     19    Evening(18~23)
# 2     12  Afternoon(12~17)
# 3      2         Dawn(0~5)
# 4      5         Dawn(0~5)
# 5     15  Afternoon(12~17)
# 6      5         Dawn(0~5)
# 7     22    Evening(18~23)
# 8     18    Evening(18~23)
# 9      7     Morning(6~11)
# 10    17  Afternoon(12~17)
# 11     8     Morning(6~11)
# 12    14  Afternoon(12~17)
# 13     7     Morning(6~11)
# 14     1         Dawn(0~5)
# 15     5         Dawn(0~5)
# 16    15  Afternoon(12~17)
# 17    12  Afternoon(12~17)
# 18     2         Dawn(0~5)
# 19    10     Morning(6~11)

# %% [markdown]
# ### (+ 선택사항) 칼럼 순서 재배치
# 데이터를 정제하는 과정에서 새로 추가 된 칼럼들을 관련 칼럼들과 나란히 재배치한다.

# %%
# columns를 복사하기 편한 list로 호출
df2.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (mm)', 'Seasons',
#        'Holiday', 'Functioning Day', 'id', 'month', 'dayname', 'weekend',
#        'WEP (mm)', 'Hour_cat'],
#       dtype='object')

# %%
# 원하는 순서로 list 재배치 및 적용
new_cols = ['id','Date', 'month', 'dayname', 'weekend', 'Hour', 'Hour_cat', 'Temperature(°C)', 'Humidity(%)',
            'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
            'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (mm)', 'WEP (mm)', 'Seasons',
            'Holiday', 'Functioning Day', 'Rented Bike Count']
df2 = df2[new_cols]
df2.to_csv('SeoulBikeData_train_2.csv', index=False) # 데이터 피쳐 엔지니어링 완료, 완료된 csv파일 저장
df2.head()
# Out:
#       id       Date  month   dayname  weekend  Hour          Hour_cat  \
# 0  10019 2018-06-05      6   Tuesday        0     1         Dawn(0~5)
# 1  13982 2018-10-30     10   Tuesday        0    19    Evening(18~23)
# 2  12391 2018-10-05     10    Friday        0    12  Afternoon(12~17)
# 3  11580 2018-02-11      2    Sunday        1     2         Dawn(0~5)
# 4  12042 2018-04-28      4  Saturday        1     5         Dawn(0~5)
#
#    Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0             20.0           67               0.7              1426
# 1              8.0           52               2.1              2000
# 2             16.6           90               1.7               518
# 3             -7.0           42               1.6              2000
# 4             10.9           81               1.7               348
#
#    Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 0                       13.6                     0.00           0.0
# 1                       -1.2                     0.00           0.0
# 2                       14.9                     0.51           2.0
# 3                      -17.7                     0.00           0.0
# 4                        7.7                     0.00           0.0
#
#    Snowfall (mm)  WEP (mm) Seasons     Holiday Functioning Day  \
# 0            0.0       0.0  Summer  No Holiday             Yes
# 1            0.0       0.0  Autumn  No Holiday             Yes
# 2            0.0       2.0  Autumn  No Holiday             Yes
# 3            0.0       0.0  Winter  No Holiday             Yes
# 4            0.0       0.0  Spring  No Holiday             Yes
#
#    Rented Bike Count
# 0                742
# 1               1442
# 2                 23
# 3                 93
# 4                152

# %% [markdown]
# # 데이터 시각화 및 분석
# 다양한 방식으로 데이터를 분석할 수 있다.
# 그래프 시각화에서는 대부분 plt, seaborn을 쓰게 되는데,
# seaborn은 통계적 시각화와 색감, 그룹 비교에 유리하며
# plt는 단조롭지만, 복잡한 커스터마이징에는 좀 더 유리한 편이다.

# %%
# 기본적인 plt 형식

# 가상의 데이터
x = ['Mon','Tue','Wed','Tur','Fri', 'Sat', 'Sun']
y = [60,30,120,30,15,30,0]

plt.figure(figsize=(8, 4)) # 그래프 사이즈 설정
plt.plot(x, y) # 그래프에 사용할 데이터 입력
plt.xlabel('Week') # x 축 라벨 이름 설정
plt.ylabel('Time') # y 축 라벨 이름 설정
plt.title('Weekly Study Time') # 그래프 제목 설정
plt.show()

# %%
# 월별 자전거 대여량 평균 라인그래프
monthly_rent = df2.groupby('month')['Rented Bike Count'].mean()

plt.plot(monthly_rent.index, monthly_rent.values, marker='o')
plt.title('Avg Rented Bike Count by Month')
plt.xlabel('Month')
plt.ylabel('Avg Rented Bike Count')
plt.grid(True)
plt.show()

# %%
# 계절별 따릉이 평균 대여량 막대그래프 보기

seasons_sort = ['Spring', 'Summer', 'Autumn', 'Winter']

fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# 기본 plt 막대 그래프
axs[0].bar(df2.groupby('Seasons')['Rented Bike Count'].mean().reindex(seasons_sort).index,
           df2.groupby('Seasons')['Rented Bike Count'].mean().reindex(seasons_sort))
axs[0].set_title('Avg Rented Bike Count by Seasons')

# seaborn 막대그래프 위의 errorbar는 편차가 적을수록 길이가 짧아진다.
sns.barplot(data=df2, x='Seasons', y='Rented Bike Count', estimator='mean', order=seasons_sort, ax=axs[1]) # 디폴트 estimator는 평균이며, sum, median, min/max, std 등을 사용할 수 있다.
axs[1].set_title('Avg Rented Bike Count by Seasons')

plt.show()

# %%
# 평일 대여량 평균 / 공휴일 대여량 평균 파이차트 시각화

holiday_mean = df2.groupby('Holiday')['Rented Bike Count'].mean().round(2)

plt.figure(figsize=(5,5))
plt.pie(holiday_mean , labels=holiday_mean.index, autopct='%1.2f%%', startangle=90)
plt.title('Avg Rented Bike Count by Holidays')
plt.axis('equal')
plt.show()

# %%
# 시간대별 평균 대여량과 온도 분포표.

fig, ax = plt.subplots(1, 2, figsize=(12, 4))


# 시간대별 평균 대여량
sns.barplot(data=df2, x='Hour_cat',
            y='Rented Bike Count', ax=ax[0])
ax[0].set_title('Avg Rented Bike Count By Hour_cat')

# Histogram - 온도 분포 파악
sns.histplot(data=df2, x=df2['Temperature(°C)'], bins=30, kde=True, ax=ax[1])
ax[1].set_title('Histogram: Temperature(°C)')

plt.tight_layout()
plt.show()

# %%
# 온도와 습도에따른 대여량 산점도 시각화

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

sns.scatterplot(data=df2, x='Temperature(°C)', y='Rented Bike Count', alpha=0.3, ax=ax[0], hue='Seasons')
ax[0].set_title('Rented Bike Count by Temperature (Seasons)')

sns.scatterplot(data=df2, x='Humidity(%)', y='Rented Bike Count', alpha=0.3, ax=ax[1], hue='Seasons')
ax[1].set_title('Rented Bike Count by Humidity (Seasons)')
plt.show()

# %%
# 회귀 그래프를 보면 산점도 + 회귀선을 볼 수 있다.

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

# Temperature vs Rented Bike Count
sns.regplot(data=df2, x='Temperature(°C)', y='Rented Bike Count', ax=ax[0], scatter_kws={'alpha': 0.3}, line_kws={'color':'orange'})
ax[0].set_title('Rented Bike Count by Temperature (Seasons)')

# Humidity vs Rented Bike Count
sns.regplot(data=df2, x='Humidity(%)', y='Rented Bike Count', ax=ax[1], scatter_kws={'alpha': 0.3}, line_kws={'color':'orange'})
ax[1].set_title('Rented Bike Count by Humidity (Seasons)')
plt.show()

# %%
# 각 Feature간의 상관관계를 살펴보고, 분석 방향을 잡아 본다.

plt.figure(figsize=(8, 6))
df2.corr(numeric_only=True)
sns.heatmap(df2.corr(numeric_only=True), annot=True, fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # 심화 학습
# 서울 따릉이 대여 정보 데이터셋을 통해 알 수 있는 데이터 자유롭게 분석 해보기

# %% [markdown]
# ## 최대한 다양한 그래프를 만들어 보자
# 하나의 타겟 변수에대한 막대그래프만 나열해 보아도 전체적인 그림을 그리기 용이하다.
# 하지만, x, y축이 모두 수치형일때는 막대 그래프로 나타내기 어려울 수 있다.

# %% [markdown]
# ### 예제

# %%
df2.columns
# Out:
# Index(['id', 'Date', 'month', 'dayname', 'weekend', 'Hour', 'Hour_cat',
#        'Temperature(°C)', 'Humidity(%)', 'Wind speed (m/s)',
#        'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (mm)', 'WEP (mm)',
#        'Seasons', 'Holiday', 'Functioning Day', 'Rented Bike Count'],
#       dtype='object')

# %%
# 범주형 칼럼의 막대그래프
cat_cols = ['month', 'dayname', 'weekend', 'Hour_cat', 'Seasons', 'Holiday']

fig, axs = plt.subplots(2, 3, figsize=(21, 12))
axs = axs.flatten() # 반복문 사용시에는 편의성을 위해 2차원 배열을 1차원으로 펴준다.

for i, col in enumerate(cat_cols):
    sns.barplot(data=df2, x=col, y='Rented Bike Count', ax=axs[i])
    axs[i].set_title(f'Avg Rented Bike Count By {col}')

plt.tight_layout()
plt.show()

# %%
# 수치형 칼럼의 히스토그램 + KDE 그래프

num_cols = ['Temperature(°C)', 'Humidity(%)', 'Wind speed (m/s)',
            'Visibility (10m)', 'Dew point temperature(°C)',
            'Solar Radiation (MJ/m2)']

fig, axs = plt.subplots(2, 3, figsize=(21, 12))
axs = axs.flatten()

for i, col in enumerate(num_cols):
    sns.histplot(data=df2, x=col, kde=True, ax=axs[i])
    axs[i].set_title(f'hist of {col}')

plt.tight_layout()
plt.show()

# %%
# 수치형 칼럼의 회귀선 그래프

fig, axs = plt.subplots(2, 3, figsize=(21, 12))
axs = axs.flatten()

for i, col in enumerate(num_cols):
    sns.regplot(data=df2, x=col, y='Rented Bike Count', ax=axs[i], scatter_kws={'alpha':0.3}, line_kws={'color':'orange'})
    axs[i].set_title(f'Rented Bike Count By {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 비와 눈이 내리더라도 대여수가 비정상적으로 높았던 날은 언제일까?

# %% [markdown]
# ### 예제

# %%
# 눈과 비가 오는날에도 대여수가 높았던 날을 파악 해본다.
plt.figure(figsize=(6, 4))
sns.boxplot(x=df2['WEP (mm)'] > 0, y=df2['Rented Bike Count'])
plt.title('Rented cnt / WEP')
plt.show()

# %%
# 비와 눈이 오는 와중에도 대여수가 유난히 많았던 이유가 있을까?

df2[(df2['WEP (mm)'] > 0) & (df2['Rented Bike Count'] > 1300)].sort_values(by='Rented Bike Count', ascending=False)
# Out:
#          id       Date  month   dayname  weekend  Hour        Hour_cat  \
# 1237  12763 2018-07-03      7   Tuesday        0    19  Evening(18~23)
# 3897  12724 2018-08-09      8  Thursday        0    18  Evening(18~23)
# 4867  10047 2018-08-30      8  Thursday        0    19  Evening(18~23)
# 6937  15730 2018-08-31      8    Friday        0     8   Morning(6~11)
# 4068  17338 2018-11-26     11    Monday        0     8   Morning(6~11)
#
#       Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 1237             30.4           62               0.9              2000
# 3897             28.1           86               2.3              1244
# 4867             25.1           74               2.1              1105
# 6937             23.1           80               0.2              1066
# 4068              2.0           84               1.1               396
#
#       Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 1237                       22.2                     0.65           0.1
# 3897                       25.5                     0.28           0.5
# 4867                       20.1                     0.00           0.5
# 6937                       19.4                     0.27           0.1
# 4068                       -0.4                     0.03           0.0
#
#       Snowfall (mm)  WEP (mm) Seasons     Holiday Functioning Day  \
# 1237           0.00      0.10  Summer  No Holiday             Yes
# 3897           0.00      0.50  Summer  No Holiday             Yes
# 4867           0.00      0.50  Summer  No Holiday             Yes
# 6937           0.00      0.10  Summer  No Holiday             Yes
# 4068           0.03      0.03  Autumn  No Holiday             Yes
#
#       Rented Bike Count
# 1237               2598
# 3897               1850
# 4867               1707
# 6937               1686
# 4068               1524

# %%
# 데이터만으로 파악하기 어려운 것들도 존재한다.

wep_mor = df2[(df2['WEP (mm)'] < 1) & (df2['WEP (mm)'] > 0) & (df2['Hour_cat'] == ('Morning(6~11)'))]['Rented Bike Count'].mean()
wep_eve = df2[(df2['WEP (mm)'] < 1) & (df2['WEP (mm)'] > 0) & (df2['Hour_cat'] == ('Evening(18~23)'))]['Rented Bike Count'].mean()

mor = df2[df2['Hour_cat'] == 'Morning(6~11)']['Rented Bike Count'].mean()
eve = df2[df2['Hour_cat'] == 'Evening(18~23)']['Rented Bike Count'].mean()

print('출퇴근시간 WEP 1.0 이하 발생시 평균 대여량:', round((wep_mor + wep_eve) / 2, 2))
print('출퇴근시간 평균 대여량:', round((mor + eve) / 2, 2))
print('전체 평균 대여량:', df2['Rented Bike Count'].mean().round(2))
# Out:
# 출퇴근시간 WEP 1.0 이하 발생시 평균 대여량: 256.41
# 출퇴근시간 평균 대여량: 841.12
# 전체 평균 대여량: 706.21

# %% [markdown]
# ## 자유롭게 시각화하여 분석하고, 활용 가능한 인사이트를 찾아보기
